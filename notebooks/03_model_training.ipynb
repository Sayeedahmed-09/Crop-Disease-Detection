# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
import importlib

import src.training.model_builder as mb
importlib.reload(mb)
# Out:
# <module 'src.training.model_builder' from 'd:\\Crop_Disease_Detection\\src\\training\\model_builder.py'>

# %%
model = mb.build_model()
model.summary()
# Out:
# Model: "CropDiseaseEfficientNetB0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import importlib
import config

importlib.reload(config)
# Out:
# <module 'config' from 'd:\\Crop_Disease_Detection\\config.py'>

# %%
import importlib
import src.training.callbacks as cb

importlib.reload(cb)
# Out:
# <module 'src.training.callbacks' from 'd:\\Crop_Disease_Detection\\src\\training\\callbacks.py'>

# %%
import importlib
import src.training.callbacks as cb

importlib.reload(cb)

callbacks = cb.get_callbacks()

print(callbacks)
# Out:
# [<keras.src.callbacks.model_checkpoint.ModelCheckpoint object at 0x0000016C784DFE00>, <keras.src.callbacks.early_stopping.EarlyStopping object at 0x0000016C78576270>, <keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x0000016C78576BA0>]

# %%
# Project Setup
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
# Import Libraries
import tensorflow as tf
import matplotlib.pyplot as plt
import importlib

import config

import src.preprocessing.data_loader as dl
import src.preprocessing.augmentation as aug
import src.training.model_builder as mb
import src.training.callbacks as cb

importlib.reload(dl)
importlib.reload(aug)
importlib.reload(mb)
importlib.reload(cb)
# Out:
# <module 'src.training.callbacks' from 'd:\\Crop_Disease_Detection\\src\\training\\callbacks.py'>

# %%
# Load Datset
train_ds, val_ds, class_names = dl.load_dataset()

print("Classes:", len(class_names))
# Out:
# Found 54305 files belonging to 38 classes.
# Using 43444 files for training.
# Found 54305 files belonging to 38 classes.
# Using 10861 files for validation.
# Classes: 38

# %%
# Create Augmentation Layer
data_augmentation = aug.get_data_augmentation()

print(data_augmentation)
# Out:
# <Sequential name=data_augmentation, built=False>

# %%
model = mb.build_model()

model.summary()
# Out:
# Model: "CropDiseaseEfficientNetB0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Compile the model
from config import LEARNING_RATE

model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE
    ),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

print("Model compiled successfully!")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model compiled successfully!

# %%
# Load Callbacks
callbacks = cb.get_callbacks()

callbacks

# %%
from config import EPOCHS

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/5
# d:\Crop_Disease_Detection\myenv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 2716/2716 ━━━━━━━━━━━━━━━━━━━━ 0s 885ms/step - accuracy: 0.8062 - loss: 0.7635
# Epoch 1: val_accuracy improved from None to 0.92791, saving model to d:\Crop_Disease_Detection\models\best_model.keras
#
# Epoch 1: finished saving model to d:\Crop_Disease_Detection\models\best_model.keras
# 2716/2716 ━━━━━━━━━━━━━━━━━━━━ 2990s 1s/step - accuracy: 0.8062 - loss: 0.7635 - val_accuracy: 0.9279 - val_loss: 0.2758 - learning_rate: 1.0000e-04
# Epoch 2/5
# 2716/2716 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9239 - loss: 0.2632
# ...
